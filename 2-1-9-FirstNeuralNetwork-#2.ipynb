# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
# define a neural network with one neuron
# for more information on TF functions see: https://www.tensorflow.org/api_docs
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])


# Niki Notes:
# Above means, we create a simplest model that contains only one unit of neuron
# in only one layer
# requiring only one input value


# use stochastic gradient descent for optimization and
# the mean squared error loss function
model.compile(optimizer='sgd', loss='mean_squared_error')

# define some training data (xs as inputs and ys as outputs)
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# fit the model to the data (aka train the model)
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 213ms/step - loss: 32.4532
# Epoch 2/500
# 1/1 [==============================] - 0s 4ms/step - loss: 25.8561
# Epoch 3/500
# 1/1 [==============================] - 0s 4ms/step - loss: 20.6592
# Epoch 4/500
# 1/1 [==============================] - 0s 5ms/step - loss: 16.5641
# Epoch 5/500
# 1/1 [==============================] - 0s 8ms/step - loss: 13.3358
# Epoch 6/500
# 1/1 [==============================] - 0s 10ms/step - loss: 10.7897
# Epoch 7/500
# 1/1 [==============================] - 0s 4ms/step - loss: 8.7805
# Epoch 8/500
# 1/1 [==============================] - 0s 7ms/step - loss: 7.1937
# Epoch 9/500
# 1/1 [==============================] - 0s 5ms/step - loss: 5.9394
# Epoch 10/500
# 1/1 [==============================] - 0s 5ms/step - loss: 4.9469
# Epoch 11/500
# 1/1 [==============================] - 0s 4ms/step - loss: 4.1604
# Epoch 12/500
# 1/1 [==============================] - 0s 3ms/step - loss: 3.5361
# ...

# %%
print(model.predict([10.0]))

# Niki Notes:
# predict if x=10.0, what's y


# Interesting! 
# I tried to change datatype from float to int and see if the result would be 19
# it did not...
# Out:
# [[18.97869]]
